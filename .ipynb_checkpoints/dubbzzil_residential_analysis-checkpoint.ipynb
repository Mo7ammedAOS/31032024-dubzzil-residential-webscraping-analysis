# %%
import pandas as pd
import

# %%
df = pd.read_csv('dubzzile.csv')

# print(df['Classification'].value_counts())
# print(df.describe())

df['new_one'] = df['Price'] * df['Area']
pd.set_option('display.max_columns',8)
pd.set_option('display.max_rows',40)
df
# Out:
#       Price  Bedroom_Number  Bath_Number  Area  ... Classification  \
# 0    125000               1            2   909  ...      Apartment
# 1    155000               2            2  1146  ...      Apartment
# 2     73000               1            1   571  ...      Apartment
# 3    300000               4            6  1632  ...          Villa
# 4     52000               1            1   422  ...      Apartment
# ..      ...             ...          ...   ...  ...            ...
# 135   60000               1            1  1208  ...      Apartment
# 136  145000               2            3  1409  ...      Apartment
# 137   60000               1            1   370  ...      Apartment
# 138  140000               2            3  1398  ...      Apartment
# 139  100000               1            2   760  ...      Apartment
#
#       Furnishing           Post_on    new_one
# 0    Unfurnished   31st March 2024  113625000
# 1    Unfurnished   31st March 2024  177630000
# 2    Unfurnished   31st March 2024   41683000
# 3      Furnished   31st March 2024  489600000
# 4      Furnished   31st March 2024   21944000
# ..           ...               ...        ...
# 135  Unfurnished   30th March 2024   72480000
# 136  Unfurnished   30th March 2024  204305000
# 137  Unfurnished   30th March 2024   22200000
# 138  Unfurnished   30th March 2024  195720000
# 139  Unfurnished   30th March 2024   76000000
#
# [140 rows x 9 columns]

# %%
df['Price'].value_counts().head(20).plot(kind='barh')
# Out:
# <Axes: ylabel='Price'>

# %%
df['Classification'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
